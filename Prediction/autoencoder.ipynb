# %%
#!/usr/bin/env python

from __future__ import print_function
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras.models import  Model
from keras.layers import Dense, Input
import numpy as np
import pandas as pd

hh101 = pd.read_csv("C:\\Users\Kiki\Downloads\PhD Data\hh101\hh101\hh101.rawdata.txt", header = None, sep='\t', names = ['Time', 'ID', 'Object', 'Room', 'Item', 'Sensor'])
#hh101 = pd.read_csv("C:\\Users\Kiki\Downloads\PhD Data\hh101\hh101\hh101.csv", header = None, names = ['timestamp', 'entity_id', 'attribute_name', 'value'])

print(hh101.columns)
print(hh101.head())
hh101 = hh101.drop(['Time'], axis=1)
#hh101 = hh101.drop(['timestamp'], axis=1)
#hh101 = hh101.replace(['TRUE', 'FALSE'],[1, 0])

samples = []
for row in hh101.iterrows():
    index, data = row
    samples.append(data.tolist())

max_words = 20000
maxlen = 3


# Tokenize values.
tokenizer = Tokenizer(num_words=max_words, lower=False)
tokenizer.fit_on_texts(samples)
sequences = tokenizer.texts_to_sequences(samples)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
data = pad_sequences(sequences, maxlen=maxlen)
print(data)
'''
log = pd.read_csv("C:\\Users\Kiki\Downloads\PhD Data\hh102\hh102\hh102.ann.features.csv")
#log = pd.read_csv(log, names=["IP", "Time", "Request", "Response"])
print(log.columns)
log = log.drop(['activity'], axis=1)

samples = []
for row in log.iterrows():
    index, data = row
    samples.append(data.tolist())

max_words = 20000
maxlen = 3

# Tokenize values.
tokenizer = Tokenizer(num_words=max_words, lower=False)
tokenizer.fit_on_texts(samples)
sequences = tokenizer.texts_to_sequences(samples)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
data = pad_sequences(sequences, maxlen=maxlen)
print(data)
'''

# Split data into training and test set. 
training_samples = int(len(samples) * 0.80)
test_samples = int(len(samples) * 0.20)

x = data[:training_samples]
x_test = data[training_samples: training_samples + test_samples]

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
    filepath='log_model-testing.h5',
    monitor='val_loss',
    save_best_only=True
    )
]

# Create model.
input_dim = x.shape[1]
input = Input(shape=(input_dim, ))
encode = Dense(3, activation='relu')(input)
encode = Dense(1, activation='relu')(encode)

decode = Dense(2, activation='relu')(encode)
decode = Dense(3, activation='sigmoid')(decode)

autoencoder = Model(input, decode)

autoencoder.summary()

autoencoder.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['accuracy'])

# Train model.
history = autoencoder.fit(x, x,
        epochs=40,
        batch_size=64,
        callbacks=callbacks_list,
        validation_data=(x_test, x_test),
        shuffle=True
        )
# Out:
# Index(['timestamp', 'entity_id', 'attribute_name', 'value'], dtype='object')
#                  timestamp               entity_id attribute_name value
# 0  2021-07-18 12:54:45.196  6CXWeD29rTaM8k3wyPKeeg       position  true
# 1  2021-07-18 12:54:45.247  2Qlk9aPijmCaAqK8tMtf74    temperature    78
# 2  2021-07-18 12:54:45.302  2Qlk9aPijmCaAqK8tMtf74        battery    85
# 3  2021-07-18 12:54:45.399  42ZtDmrqrjNy6jrMWIXWlO    temperature    25
# 4  2021-07-18 12:54:45.472  42ZtDmrqrjNy6jrMWIXWlO        battery    82
# Found 132 unique tokens.
# [[ 58   6   3]
#  [ 84  29 121]
#  [ 84  44 111]
#  ...
#  [  9   4  74]
#  [ 14   4  53]
#  [  8   4  71]]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 3)                 12
#
#  dense_1 (Dense)             (None, 1)                 4
#
#  dense_2 (Dense)             (None, 2)                 4
#
#  dense_3 (Dense)             (None, 3)                 9
#
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 20791/20791 [==============================] - 19s 890us/step - loss: 300.1211 - accuracy: 0.3440 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 2/40
# 20791/20791 [==============================] - 18s 858us/step - loss: 300.0547 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225loss: 298.854 - ETA: 5s - loss: 2 - ETA: 5s - loss: 2 - ETA: 4s - loss: - ETA: 3s - loss: 299.5634 - accura - ETA: 3s - loss: 299.5918 - accura - ETA: 3s -
# Epoch 3/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0574 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 4/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0553 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 5/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0567 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.522513s - ETA: 6s - loss: 299.7866
# Epoch 6/40
# 20791/20791 [==============================] - 18s 846us/step - loss: 300.0555 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225796 - accuracy:  - ETA: 10s - loss: 300.4737 - accur - ETA: 10s - - - ETA: 8s - loss: 300.2401 - accuracy - ETA - ETA: 1s - loss: 300.2071 - ac - ETA: 0s - loss:
# Epoch 7/40
# 20791/20791 [==============================] - 18s 851us/step - loss: 300.0558 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225ss: 298.9079 - accu - ETA: 11s - loss: 299.7622 - accura - ETA: 11s - loss: 299.9762 - accuracy: 0 - ETA: 11s - loss: 300.3401 - accuracy: 0.515 - ETA: 11s - loss: 300.4487 - ac - ETA: 10s - loss: 300.8364 - accuracy:  - ETA - ETA: 6s - loss: 300.7750 - accuracy: 0. - ETA: 6s - loss: 300 - ETA: 5s - loss: 300.677 - ETA: 5s - loss: 300.9308 - accura - E - ETA: 4s - loss: 300.4592 - ac - ETA: 3s - loss: 300 - ETA - ETA: 2s - loss: 300 - ETA: 0s - loss: 300.129
# Epoch 8/40
# 20791/20791 [==============================] - 18s 854us/step - loss: 300.0554 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225- los
# Epoch 9/40
# 20791/20791 [==============================] - 18s 847us/step - loss: 300.0560 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.522512s - loss: 299.4413 - accuracy: 0.51 - ETA: 12s - loss: 299.754 - ETA: 11s - loss: 299.0864 - accuracy: 0.51 - ETA:  - - ETA: 1s - - ETA: 0s - loss:
# Epoch 10/40
# 20791/20791 [==============================] - 18s 848us/step - loss: 300.0554 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225: 300.8504 -  - ETA:
# Epoch 11/40
# 20791/20791 [==============================] - 18s 852us/step - loss: 300.0538 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225s - loss: 2 - ETA: 0s - loss: 299.8849 -
# Epoch 12/40
# 20791/20791 [==============================] - 18s 858us/step - loss: 300.0563 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.52258s - loss: 300.5
# Epoch 13/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0570 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225: 13s - loss: 300.5806 - - ETA: 12s - loss:  - ETA: 11s - loss: 300.2096 - accuracy: 0. - ETA - ETA:  - ETA: 6s - ETA: 0s - loss: 300.0755 - accuracy - ETA: 0s - loss: 300.0593 - accura - ETA: 0s - loss: 300.1418 -
# Epoch 14/40
# 20791/20791 [==============================] - 18s 854us/step - loss: 300.0552 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 accuracy: 0.51 -  - ETA: 5s - loss:
# Epoch 15/40
# 20791/20791 [==============================] - 18s 855us/step - loss: 300.0559 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225loss: 299.8528 -  - ETA: 5s - loss: 299.7409 - accura - ETA: 5s - loss:
# Epoch 16/40
# 20791/20791 [==============================] - 18s 848us/step - loss: 300.0547 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 - loss: 300.5403 - accuracy: 0.518 - ETA: 13 - ETA: 11s - loss: 300.2499 - acc - ETA: 11s - loss: 300. - ETA: 10s - loss: 299.6 - ETA: 9s - loss: 2 - ETA: 7s - loss: 2
# Epoch 17/40
# 20791/20791 [==============================] - 18s 854us/step - loss: 300.0558 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225ss: 299.0136 - acc - ETA: 13s - loss: 300.9340 - accuracy: 0.515 - ETA: 13s - loss: 300.8123 - accuracy: 0.51 - ETA: 13s - loss: 300.9431 - a - ETA: 7s - loss: 300.538 - - ETA - ETA: 1s - loss: 300 - ETA: 0s - loss: 300.1502 - accura - ETA: 0s - loss: 299.9773 - accura - ETA: 0s - loss: 300.0314 - ac - ETA: 0s - loss: 300.0954 - accuracy: 0.51
# Epoch 18/40
# 20791/20791 [==============================] - 18s 850us/step - loss: 300.0553 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225ss: 301.5710 - accuracy: 0.51 - ETA: 13s - loss: 30 - ETA: 11s - loss: 300.7375 - accuracy: 0.51 - ETA: 11s - loss: 300.742 - ETA: 10s - loss: 300.9244  - ETA: 9s - loss: 300.6668 -  - E - ETA: 4s - loss: 300.1866 - accu - ETA: 4s - loss: 299.9702 - accuracy:  - ETA: 4s - loss: 299.9306 - accu - ETA: 4s - loss: 299.8412 - accu - ETA: 3s - loss: 299.7140 -
# Epoch 19/40
# 20791/20791 [==============================] - 18s 857us/step - loss: 300.0551 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 - loss: 300.0102 - accuracy:  - ETA: 1s - los - ETA: 0s - l - ETA: 0s - loss: 300.0588 - accuracy: 0.
# Epoch 20/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0554 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 21/40
# 20791/20791 [==============================] - 18s 854us/step - loss: 300.0561 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225A: 1s - loss: 300.1131 - accuracy: 0.51 - ETA: 1s - loss: 300 -
# Epoch 22/40
# 20791/20791 [==============================] - 18s 852us/step - loss: 300.0552 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225179 - accuracy: 0.5 - ETA: 10s - loss: 301.1610 - accuracy: 0.51 - ETA: 10s - l - ETA: 1s - loss: 299.9463 - accuracy: 0. - ETA: 1s - loss: 299.9572 - accuracy:  - ETA: 1s - loss: 299.9909 - accura - ETA: 0s - loss: 300.0649  - ETA: 0s - loss: 300.0990 - accuracy:  - ETA: 0s - loss: 300.1169 - accu
# Epoch 23/40
# 20791/20791 [==============================] - 18s 852us/step - loss: 300.0557 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 - accuracy: 0. - ETA:  - ETA: 4s - loss: 299.2393 - accuracy:  - ETA: 4s - - ETA:  - ETA: 2s - loss: 299.6219 - accuracy: 0.51 - E
# Epoch 24/40
# 20791/20791 [==============================] - 18s 855us/step - loss: 300.0553 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225: 3 - ETA: 4s - ETA: 3s - loss: 300.3190 - accura - ETA: 3s - loss: 300.2679 - accuracy: 0. - ETA - ETA: 2s - l - ETA: 1s - l - ETA: 0s - loss: 300.1696 - accura - ETA: 0s - loss: 300
# Epoch 25/40
# 20791/20791 [==============================] - 18s 856us/step - loss: 300.0553 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225ETA: 0s - loss: 300.2035 - accuracy: 0. - ETA: 0s - loss:
# Epoch 26/40
# 20791/20791 [==============================] - 18s 857us/step - loss: 300.0551 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.522516 - accu - ETA:  - ETA: 1s - loss: 300.1660 - accuracy: 0.51 - ETA: 1s - loss: 300 - ETA: 0s - loss: 300.1
# Epoch 27/40
# 20791/20791 [==============================] - 18s 859us/step - loss: 300.0556 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225- ETA: 7s - loss: 299.589 - ETA: 6s - loss: 299.5073 - ac - ETA: 6s - loss: 2 - ETA: 5s - loss: 299.4528 -  - ETA: 5s - ETA - ETA: 3s - loss: 299.5383 - accuracy: 0. - ETA: 3s - - ETA: 1s - loss: 299.7105 - accu - ETA: 0s - loss: - ETA: 0s - loss: 300.0585 - accuracy: 0.51
# Epoch 28/40
# 20791/20791 [==============================] - 18s 856us/step - loss: 300.0567 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 accuracy: 0.51 - ETA: 3s - loss: - ETA: 1s - ETA: 0s - loss: 300.1492 - accuracy - ETA: 0s - loss: 300.0292 - accuracy: 0.
# Epoch 29/40
# 20791/20791 [==============================] - 18s 851us/step - loss: 300.0562 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225ss: 299.2333 - accurac - ETA: 11s - loss:  - ETA - ETA: 5s - loss: 299.8440  - ETA: 3s - ETA: 2s - ETA: 1s - loss: 299.6267 - accuracy: 0.51 - ETA: 1s - loss: 299.6870 - accuracy - - ETA: 0s - loss: 300
# Epoch 30/40
# 20791/20791 [==============================] - 18s 850us/step - loss: 300.0553 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 31/40
# 20791/20791 [==============================] - 18s 853us/step - loss: 300.0565 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 1s - loss: 300.2873 - accuracy: 0. - E - ETA: 0s - loss: 300.2
# Epoch 32/40
# 20791/20791 [==============================] - 18s 870us/step - loss: 300.0560 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 33/40
# 20791/20791 [==============================] - 19s 893us/step - loss: 300.0558 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 34/40
# 20791/20791 [==============================] - 18s 879us/step - loss: 300.0557 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 - ETA: 1s - - ETA: 0s - loss: 299.8723
# Epoch 35/40
# 20791/20791 [==============================] - 18s 883us/step - loss: 300.0554 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 36/40
# 20791/20791 [==============================] - 18s 880us/step - loss: 300.0551 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225298.9002 - accuracy - ETA: 7s - - ETA: 5s - loss: 299.2668 -  - ETA: 0s - loss: 300.1049 - accuracy:  - ETA: 0s - loss: 300.0420 - accura
# Epoch 37/40
# 20791/20791 [==============================] - 18s 881us/step - loss: 300.0554 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225: 301.4329 - accuracy: - ETA: 14s - loss: 301.8028 - a - ETA: 13s -  - ETA: 8s - - ETA: 4s - loss: 2
# Epoch 38/40
# 20791/20791 [==============================] - 18s 879us/step - loss: 300.0562 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225
# Epoch 39/40
# 20791/20791 [==============================] - 18s 881us/step - loss: 300.0566 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225 - accuracy: 0. - ETA: 0s - loss: 300.0414 - accuracy - ETA: 0s - loss:
# Epoch 40/40
# 20791/20791 [==============================] - 18s 883us/step - loss: 300.0559 - accuracy: 0.5154 - val_loss: 354.0474 - val_accuracy: 0.5225

# %%
import pandas as pd
from numpy import vstack
#import seaborn as sns

# Combined x and x_test.
new_x = vstack([x, x_test])

predictions = autoencoder.predict(new_x)

# Calculated MSE.
mse = np.mean(np.power(new_x - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse})

# Set threshold at the 99th quartile.
threshold = error_df.quantile(0.99)


error_df.describe()
# Out:
#        reconstruction_error
# count          1.663230e+06
# mean           4.103564e+02
# std            7.921680e+02
# min            1.233333e+01
# 25%            1.500000e+01
# 50%            2.833333e+01
# 75%            5.176667e+02
# max            9.015000e+03

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Reconstruction error binned and plotted.
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(error_df.reconstruction_error.values, bins=7)

#sns.histplot(error_df.reconstruction_error.values, binwidth=8)
# Out:
# (array([1.506494e+06, 1.043160e+05, 3.977000e+04, 6.691000e+03,
#         4.144000e+03, 1.456000e+03, 3.590000e+02]),
#  array([  12.33333333, 1298.42857143, 2584.52380952, 3870.61904762,
#         5156.71428571, 6442.80952381, 7728.9047619 , 9015.        ]),
#  <BarContainer object of 7 artists>)

# %%
threshold = threshold

# Plot reconstruction error vs. the data.
fig, ax = plt.subplots()
ax.plot(error_df.index, error_df.reconstruction_error, marker='o', ms=3.5, linestyle='')
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='threshold')
ax.legend(loc=5)
plt.title("Reconstruction error")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# Output anomalies.
index_list = []
for index, row in error_df.iterrows():
    if row.reconstruction_error > int(threshold):
        index_list.append(index)

output = []    
for x in index_list:
    output.append(new_x[x])
  
for x in output:
    for key, value in word_index.items():
        if value == x[2]:
            print(key)
        if value == x[1]:
            print(key)
        if value == x[0]:
            print(key)
    print('----------------------------------')
# Out:
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 78
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 85
# ----------------------------------
# battery
# 2cCL4CyTHQ3hXU1AUigzsM
# 82
# ----------------------------------
# true
# position
# 4uAQxNoZe3Vl3wEl5VAJI1
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 100
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 100
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 100
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 100
# ----------------------------------
# 5DBHIfps52IPRa8EirsD6x
# battery
# 100
# ----------------------------------
# 4qV5f8jcBDVtvPBty2NYtD
# battery
# 100
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 100
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 48
# ----------------------------------
# battery
# 5Kcixoulb3F5WZO138ZSsP
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# 5CmUIV8qwRLknv6rgc5a7t
# battery
# 100
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 76
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 80
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 82
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 81
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 78
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 7P6GpxIomHcfKP1MZpdI3q
# 77
# ----------------------------------
# brightness
# 6ntn0fnLClzMGcVZswMWRb
# 98
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 71W6rKSdOXRuJTG8eYmO27
# 98
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 98
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 98
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 98
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 67
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 67
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 98
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 68
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 69
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 68
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 98
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 98
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 39
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 55
# ----------------------------------
# brightness
# 32
# 5Kcixoulb3F5WZO138ZSsP
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 37
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 33
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 48
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 45
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 45
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 43
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 43
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 45
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 44
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 47
# ----------------------------------
# brightness
# 28
# 5Kcixoulb3F5WZO138ZSsP
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 45
# ----------------------------------
# brightness
# 28
# 5Kcixoulb3F5WZO138ZSsP
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 47
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 40
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 40
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 41
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 40
# ----------------------------------
# brightness
# 5Kcixoulb3F5WZO138ZSsP
# 40
# ----------------------------------
# brightness
# 4qV5f8jcBDVtvPBty2NYtD
# 98
# ----------------------------------
# brightness
# 3Ge72Lb61T2Yrrnj7rHKN0
# 98
# ----------------------------------
# brightness
# 4qV5f8jcBDVtvPBty2NYtD
# 53
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 100
# ----------------------------------
# battery
# 2cCL4CyTHQ3hXU1AUigzsM
# 100
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 100
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 100
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 100
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 100
# ----------------------------------
# 5DBHIfps52IPRa8EirsD6x
# battery
# 100
# ----------------------------------
# 4qV5f8jcBDVtvPBty2NYtD
# battery
# 100
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 100
# ----------------------------------
# battery
# 5Kcixoulb3F5WZO138ZSsP
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# 5CmUIV8qwRLknv6rgc5a7t
# battery
# 100
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 67
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 100
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 100
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 6ntn0fnLClzMGcVZswMWRb
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 22
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 23
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 23
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 99
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 3Ge72Lb61T2Yrrnj7rHKN0
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 3Ge72Lb61T2Yrrnj7rHKN0
# 55
# ----------------------------------
# brightness
# 6ntn0fnLClzMGcVZswMWRb
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 98
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 98
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 25
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 24
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 97
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 99
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 99
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 99
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 99
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 55
# ----------------------------------
# temperature
# 26
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# brightness
# 6zknLOyttl8U3KZ6FstT6j
# 57
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 100
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 95
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 57
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# brightness
# 5CmUIV8qwRLknv6rgc5a7t
# 53
# ----------------------------------
# temperature
# 30
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 100
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 55
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 98
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 99
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 57
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 98
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 99
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 100
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 99
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 96
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# ...
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# 5CmUIV8qwRLknv6rgc5a7t
# battery
# 79
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 83
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 80
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 71
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 84
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 79
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 78
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 76
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 79
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# 5CmUIV8qwRLknv6rgc5a7t
# battery
# 79
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 83
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 81
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 70
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 78
# ----------------------------------
# temperature
# 30
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 79
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 73
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 82
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 81
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 73
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 78
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 75
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 82
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 79
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 72
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 53
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 81
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# temperature
# 29
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# temperature
# 28
# 2cCL4CyTHQ3hXU1AUigzsM
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 75
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 83
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 79
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 72
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 78
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# brightness
# 3tqYOfEXDrOHkbGPFGK6Db
# 57
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# battery
# 7P6GpxIomHcfKP1MZpdI3q
# 83
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 81
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 76
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# brightness
# 2QpbQO34UZeLqX2DMfFNvt
# 98
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 83
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 72
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 77
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 80
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 82
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 75
# ----------------------------------
# 3NtIg6iWXBnRlPLVouPyO6
# battery
# 78
# ----------------------------------
# 6ntn0fnLClzMGcVZswMWRb
# battery
# 80
# ----------------------------------
# 38Z88xbdQh1MutZupTgrus
# battery
# 73
# ----------------------------------
# 6zknLOyttl8U3KZ6FstT6j
# battery
# 83
# ----------------------------------
# 27kTFz7Lq4xpKHNFMsuSgT
# battery
# 79
# ----------------------------------
# 6TcIAFzYSgpwcByD2CFMY5
# battery
# 84
# ----------------------------------
# 2QpbQO34UZeLqX2DMfFNvt
# battery
# 79
# ----------------------------------
# 3Ge72Lb61T2Yrrnj7rHKN0
# battery
# 81
# ----------------------------------
# 3tqYOfEXDrOHkbGPFGK6Db
# battery
# 75
# ----------------------------------
# 71W6rKSdOXRuJTG8eYmO27
# battery
# 83
# ----------------------------------
# temperature
# 28
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# temperature
# 27
# 7P6GpxIomHcfKP1MZpdI3q
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------
# brightness
# 38Z88xbdQh1MutZupTgrus
# 55
# ----------------------------------

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1 , len(acc) + 1)

plt.plot(epochs, acc, 'ro', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
